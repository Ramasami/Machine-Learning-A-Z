# %% [markdown]
# # Simple Linear Regression

# %% [markdown]
# ## Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Read Data

# %%
# %cd "drive/MyDrive/Projects/Machine-Learning-A-Z/Regression/Decision Tree Regression"
# Out:
# /content/drive/Othercomputers/Predator/Projects/Machine-Learning-A-Z/Regression/Decision Tree Regression

# %%
# !ls
# Out:
# decision_tree_regression.ipynb	Position_Salaries.csv

# %%
dataset = pd.read_csv("Position_Salaries.csv")
dataset
# Out:
#             Position  Level   Salary
# 0   Business Analyst      1    45000
# 1  Junior Consultant      2    50000
# 2  Senior Consultant      3    60000
# 3            Manager      4    80000
# 4    Country Manager      5   110000
# 5     Region Manager      6   150000
# 6            Partner      7   200000
# 7     Senior Partner      8   300000
# 8            C-level      9   500000
# 9                CEO     10  1000000

# %% [markdown]
# ## Define input and output variables

# %%
X = dataset.iloc[:,1].values.reshape(-1,1)
y = dataset.iloc[:,-1].values.reshape(-1,1)

# %%
plt.scatter(X,y, color='red')
plt.plot(X,y)
plt.title("Level vs Salary")
plt.xlabel("Level")
plt.ylabel("Salary")
plt.show()

# %% [markdown]
# ## Training Simple Linear Regression Model

# %%
from sklearn.tree import DecisionTreeRegressor
regressor = DecisionTreeRegressor(random_state = 0)
regressor.fit(X, y)
y_pred = regressor.predict(X)

# %%
plt.scatter(X,y, color='red')
plt.plot(X,y_pred)
plt.title("Level vs Salary")
plt.xlabel("Level")
plt.ylabel("Salary")
plt.show()

# %%
X_grid = np.arange(min(X.reshape(-1)),max(X.reshape(-1)), 0.1)
y_grid = regressor.predict(X_grid.reshape(-1, 1))
plt.scatter(X,y, color='red')
plt.plot(X_grid,y_grid)
plt.title("Level vs Salary")
plt.xlabel("Level")
plt.ylabel("Salary")
plt.show()
