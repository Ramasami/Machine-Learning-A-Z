# %% [markdown]
# # Simple Linear Regression

# %% [markdown]
# ## Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Read Data

# %%
# %cd "drive/MyDrive/Projects/Machine-Learning-A-Z/Regression/Polynomial Regression"
# Out:
# /content/drive/Othercomputers/Predator/Projects/Machine-Learning-A-Z/Regression/Polynomial Regression

# %%
# !ls
# Out:
# polynomial_regression.ipynb  Position_Salaries.csv

# %%
dataset = pd.read_csv("Position_Salaries.csv")
dataset
# Out:
#             Position  Level   Salary
# 0   Business Analyst      1    45000
# 1  Junior Consultant      2    50000
# 2  Senior Consultant      3    60000
# 3            Manager      4    80000
# 4    Country Manager      5   110000
# 5     Region Manager      6   150000
# 6            Partner      7   200000
# 7     Senior Partner      8   300000
# 8            C-level      9   500000
# 9                CEO     10  1000000

# %% [markdown]
# ## Define input and output variables

# %%
X = dataset.iloc[:,1].values.reshape(-1,1)
y = dataset.iloc[:,-1].values

# %%
plt.scatter(X,y, color='red')
plt.plot(X,y)
plt.title("Level vs Salary")
plt.xlabel("Level")
plt.ylabel("Salary")
plt.show()

# %% [markdown]
# ## Training Simple Linear Regression Model

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X, y)
y_pred = regressor.predict(X)
regressor.coef_, regressor.intercept_
# Out:
# (array([80878.79]), -195333.33333333337)

# %%
np.set_printoptions(precision=2)
np.concatenate((y_pred.reshape(-1,1), y.reshape(-1,1)), axis = 1)
# Out:
# array([[-114454.55,   45000.  ],
#        [ -33575.76,   50000.  ],
#        [  47303.03,   60000.  ],
#        [ 128181.82,   80000.  ],
#        [ 209060.61,  110000.  ],
#        [ 289939.39,  150000.  ],
#        [ 370818.18,  200000.  ],
#        [ 451696.97,  300000.  ],
#        [ 532575.76,  500000.  ],
#        [ 613454.55, 1000000.  ]])

# %%
plt.scatter(X,y, color='red')
plt.plot(X,y_pred)
plt.title("Level vs Salary")
plt.xlabel("Level")
plt.ylabel("Salary")
plt.show()

# %% [markdown]
# ## Adding Polynomial Data

# %%
from sklearn.preprocessing import PolynomialFeatures
poly_reg = PolynomialFeatures(degree = 2)
X_poly = poly_reg.fit_transform(X)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_poly, y)
y_pred = regressor.predict(X_poly)
regressor.coef_, regressor.intercept_
# Out:
# (array([      0.          , -132871.2121212121,   19431.8181818182]),
#  232166.6666666664)

# %%
np.set_printoptions(precision=2)
np.concatenate((y_pred.reshape(-1,1), y.reshape(-1,1)), axis = 1)
# Out:
# array([[ 118727.27,   45000.  ],
#        [  44151.52,   50000.  ],
#        [   8439.39,   60000.  ],
#        [  11590.91,   80000.  ],
#        [  53606.06,  110000.  ],
#        [ 134484.85,  150000.  ],
#        [ 254227.27,  200000.  ],
#        [ 412833.33,  300000.  ],
#        [ 610303.03,  500000.  ],
#        [ 846636.36, 1000000.  ]])

# %%
plt.scatter(X,y, color='red')
plt.plot(X,y_pred)
plt.title("Level vs Salary")
plt.xlabel("Level")
plt.ylabel("Salary")
plt.show()

# %% [markdown]
# ## Predictions vs Real
